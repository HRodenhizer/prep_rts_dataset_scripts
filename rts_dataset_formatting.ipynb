# %% [markdown]
# # RTS Dataset Formatting

# %% [markdown]
# # TODO
#
# -  Make the script find and download the current version of the RTS dataset and metadata description rather than providing the filepath manually
# - remove filepaths and metadata columns that I set
# -  think through environment sharing (rts_dataset.rproj, .env, renv)
# -  finalize file organization/filepaths so that they don't differ between R and Python

# %% [markdown]
# # Set-Up

# %%
import os
import uuid
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## User-Defined Input
#
# Before starting, copy your new file into the data directory of this rproject.
#
# Provide the file name to the data:

# %%
new_data_file = 'rts_dataset_test_polygons_new.shp'  # set this
new_data_filepath = os.path.join(
  'input_data',
  new_data_file)

# %% [markdown]
# Provide the names of any metadata fields in your new file that are not already in the official RTS Data Set (please check the list to ensure that the field has not been included previously):

# %%
# Use the format `AbbreviatedName: FullName`, where the FullName should be a human-readable name and the AbbreviatedName should be the ESRI shapefile driver abbreviated version of the the FullName.
# Example:
# new_fields = {'CstmCl1': 'CustomColumn1'}
new_fields = {'CstmCl1' : 'CustomColumn1'}

# %% [markdown]
# # Functions

# %%
def filter_all(df, columns):
    
    
def ChangeColumnNames(DataFrameFileLocation):
    x = DictKeyValuesFromText()
    df = pd.read_csv(DataFrameFileLocation)
    for y in df.columns:
        if y not in x.keys():
            i = input("The column " +  y +  " is not in the list, give a name:")
            df.rename(columns={y:i}) 
        else:
            df.rename(columns={y:x[y]})

    return df

# %% [markdown]
# # Import Metadata Description File

# %%
### update this to download the current version automatically ##################
col_metadata = pd.read_csv('metadata_description.csv')
################################################################################

required_fields = (
    pd.Series(
        col_metadata[col_metadata.Required == True].FullColumnName.values, 
        index = col_metadata[col_metadata.Required == True].AbbreviatedColumnName
    )
    .to_dict()
)
optional_fields = (
    pd.Series(
        col_metadata[col_metadata.Required == False].FullColumnName.values, 
        index = col_metadata[col_metadata.Required == False].AbbreviatedColumnName
    )
    .to_dict()
)

# %% [markdown]
# # Import Official and New RTS Data Files

# %%
### update this to find the dataset online and download it #####################
rts_data_filepath = os.path.join(
  'input_data',
  'rts_dataset_test_polygons_current.shp'
  )

rts_data = (
    gpd.read_file(rts_data_filepath)
    .rename(columns = dict(required_fields, **optional_fields))
    .filter(items = list(required_fields.values()) + list(optional_fields.values())) # Need to check if all required_columns are present
)

rts_data
################################################################################
# Out:
#     CentroidLat    CentroidLon   RegionName  CreatorLab ContributionDate  \
# 0  2.007193e+06  866061.465348  Yamal-Gydan  Rodenhizer       2023-09-01
# 1  2.007241e+06  866081.519711  Yamal-Gydan  Rodenhizer       2023-09-01
# 2  2.007316e+06  865833.552436  Yamal-Gydan  Rodenhizer       2023-09-01
# 3  2.007461e+06  865774.720010  Yamal-Gydan  Rodenhizer       2023-09-01
# 4  2.007509e+06  865939.506882  Yamal-Gydan  Rodenhizer       2023-09-01
# 5  2.007494e+06  866015.061823  Yamal-Gydan  Rodenhizer       2023-09-01
#
#              BaseMapDate BaseMapSource  BaseMapResolution FeatureType  \
# 0  01-05-2022,30-09-2022   WorldView-2                4.0    positive
# 1  01-05-2022,30-09-2022   WorldView-2                4.0    positive
# 2  01-05-2022,30-09-2022   WorldView-2                4.0    positive
# 3  01-05-2022,30-09-2022   WorldView-2                4.0    positive
# 4  01-05-2022,30-09-2022   WorldView-2                4.0    positive
# 5  01-05-2022,30-09-2022   WorldView-2                4.0    positive
#
#                                    UUID
# 0  d5d6c116-c34c-54fc-9f2a-bbec1ab93e0f
# 1  87fa1497-685e-59f8-98e9-503f3fa10943
# 2  b59a55d1-6a53-5c96-9a07-d8f0e5df1e91
# 3  b471ff03-b293-504c-8840-d98c405c3bed
# 4  4d919491-34fb-577e-9941-c7698a30feb9
# 5  96eff848-0c55-5d53-992c-5760e175d651

# %%
new_data = (
    gpd.read_file(new_data_filepath)
    .rename(columns = dict(
        {key:required_fields[key] for key in [key for key in list(required_fields.keys()) if key != 'UUID']},
        **optional_fields,
        **new_fields
        )
            )
    .filter(items = list(required_fields.values()) + list(optional_fields.values()) + list(new_fields.values())) 
    # Need to check if all required_columns are present
    )
new_data
# Out:
#     CentroidLat    CentroidLon   RegionName  CreatorLab ContributionDate  \
# 0  2.007205e+06  866070.126157  Yamal-Gydan  Rodenhizer       2023-09-28
# 1  2.007299e+06  866170.840949  Yamal-Gydan  Rodenhizer       2023-09-28
# 2  2.007313e+06  865829.604614  Yamal-Gydan  Rodenhizer       2023-09-28
# 3  2.007456e+06  865841.019260  Yamal-Gydan  Rodenhizer       2023-09-28
# 4  2.007497e+06  865952.953772  Yamal-Gydan  Rodenhizer       2023-09-28
# 5  2.007483e+06  866010.935801  Yamal-Gydan  Rodenhizer       2023-09-28
# 6  2.007299e+06  866170.840949  Yamal-Gydan  Rodenhizer       2023-09-28
#
#              BaseMapDate BaseMapSource  BaseMapResolution FeatureType  \
# 0  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 1  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 2  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 3  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 4  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 5  01-05-2023,30-09-2023   WorldView-2                4.0    positive
# 6   01-05-2022,30-9-2022   WorldView-2                4.0    positive
#
#    CustomColumn1
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN

# %%
test = list(required_fields.values()) + list(optional_fields.values()) + list(new_fields.values())
test
# Out:
# ['CentroidLat',
#  'CentroidLon',
#  'RegionName',
#  'CreatorLab',
#  'ContributionDate',
#  'BaseMapDate',
#  'BaseMapSource',
#  'BaseMapResolution',
#  'FeatureType',
#  'UUID',
#  'CustomColumn1']

# %%
optional_fields
# Out:
# {'Area': 'Area'}
